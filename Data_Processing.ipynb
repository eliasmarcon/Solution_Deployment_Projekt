# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
dataframe = pd.read_csv("./Dataset/Balloon Race_ Data Breaches - LATEST - breaches.csv")

# %%
dataframe_raw = dataframe[1:]

# %%
dataframe_raw2 = dataframe_raw.drop(['alternative name', 'story', 'interesting story', 'displayed records', 'Unnamed: 11', '1st source link', '2nd source link'], axis = 1)
dataframe_raw2
# Out:
#                     organisation records lost year          date  \
# 1                           Plex   15,000,000    2022   Aug 2022
# 2                        Twitter    5,400,000    2021   Dec 2021
# 3                Shanghai Police  500,000,000    2022   Jul 2022
# 4       City of Amagasaki, Japan      500,000    2022   Jun 2022
# 5         Dubai Real Estate Leak      800,000    2022   May 2022
# ..                           ...          ...     ...        ...
# 413              Hewlett Packard      200,000    2006   Mar 2006
# 414              Ameritrade Inc.      200,000    2005   Apr 2005
# 415                    Citigroup    3,900,000    2005   Jun 2005
# 416  Cardsystems Solutions Inc.    40,000,000    2005   Jun 2005
# 417                          AOL   92,000,000    2004   Jun 2004
#
#            sector        method data sensitivity        source name     ID
# 1            web         hacked                1       Ars technica  418.0
# 2             web        hacked                2  Bleeping Computer  419.0
# 3       financial        hacked                5       The Register  420.0
# 4      government         oops!                3                BBC  421.0
# 5       financial    inside job                1                E24  417.0
# ..            ...           ...              ...                ...    ...
# 413  tech, retail  lost device                 2    Computer Weekly    6.0
# 414       finance  lost device                 2                NBC    5.0
# 415       finance  lost device                 3           NY Times    4.0
# 416       finance        hacked                3              Wired    3.0
# 417           web    inside job                1                CNN    2.0
#
# [417 rows x 9 columns]

# %%
# trim method
dataframe_raw2 = dataframe_raw2.rename(columns = lambda x : x.strip())
dataframe_raw2.columns = dataframe_raw2.columns.str.replace(' ', '_')

# select Monthname from date
dataframe_raw2['month'] = pd.to_datetime(dataframe_raw2.date).dt.to_period('m').dt.strftime('%B')

# transfrom records lost to int
dataframe_raw2['records_lost'] = dataframe_raw2['records_lost'].str.replace(",", "").astype(int)

# remove NaN values
dataframe_raw2['data_sensitivity'] = dataframe_raw2['data_sensitivity'].fillna(0) 

# transform string columns into int
dataframe_raw2[['ID', 'year', 'data_sensitivity']] = dataframe_raw2[['ID', 'year', 'data_sensitivity']].astype(int)

# split sector into sector 1 and sector 2
dataframe_raw2[['sector_1', 'sector_2']] = dataframe_raw2['sector'].str.split(',', n = 1, expand = True)
dataframe_raw2['sector_2'] = dataframe_raw2['sector_2'].fillna('No other sector') 

# change Sektor financial zu finance
dataframe_raw2['sector_1'] = dataframe_raw2['sector_1'].replace('financial', 'finance')


# add Sensitivity describtion
condlist = [
                (dataframe_raw2['data_sensitivity'] == 0),
                (dataframe_raw2['data_sensitivity'] == 1),
                (dataframe_raw2['data_sensitivity'] == 2),
                (dataframe_raw2['data_sensitivity'] == 3),
                (dataframe_raw2['data_sensitivity'] == 4),
                (dataframe_raw2['data_sensitivity'] == 5)
            ]

choicelist = ['Unknown', 'Just email address/Online information', 'SSN/Personal details', 'Credit card information', 'Health & other personal records', 'Full details']

dataframe_raw2['data_sensitivity_text'] = np.select(condlist, choicelist)

# %%
def whitespace_remover(dataframe):
   
    # iterating over the columns
    for i in dataframe.columns:
         
        # checking datatype of each columns
        if dataframe[i].dtype == 'object':
             
            # applying strip function on column
            dataframe[i] = dataframe[i].map(str.strip)
            
        else:
             
            # if condn. is False then it will do nothing.
            pass
 
# applying whitespace_remover function on dataframe
whitespace_remover(dataframe_raw2)

# %%
dataframe_raw2
# Out:
#                    organisation  records_lost  year      date        sector  \
# 1                          Plex      15000000  2022  Aug 2022           web
# 2                       Twitter       5400000  2021  Dec 2021           web
# 3               Shanghai Police     500000000  2022  Jul 2022     financial
# 4      City of Amagasaki, Japan        500000  2022  Jun 2022    government
# 5        Dubai Real Estate Leak        800000  2022  May 2022     financial
# ..                          ...           ...   ...       ...           ...
# 413             Hewlett Packard        200000  2006  Mar 2006  tech, retail
# 414             Ameritrade Inc.        200000  2005  Apr 2005       finance
# 415                   Citigroup       3900000  2005  Jun 2005       finance
# 416  Cardsystems Solutions Inc.      40000000  2005  Jun 2005       finance
# 417                         AOL      92000000  2004  Jun 2004           web
#
#           method  data_sensitivity        source_name   ID     month  \
# 1         hacked                 1       Ars technica  418    August
# 2         hacked                 2  Bleeping Computer  419  December
# 3         hacked                 5       The Register  420      July
# 4          oops!                 3                BBC  421      June
# 5     inside job                 1                E24  417       May
# ..           ...               ...                ...  ...       ...
# 413  lost device                 2    Computer Weekly    6     March
# 414  lost device                 2                NBC    5     April
# 415  lost device                 3           NY Times    4      June
# 416       hacked                 3              Wired    3      June
# 417   inside job                 1                CNN    2      June
#
#        sector_1         sector_2                  data_sensitivity_text
# 1           web  No other sector  Just email address/Online information
# 2           web  No other sector                   SSN/Personal details
# 3       finance  No other sector                           Full details
# 4    government  No other sector                Credit card information
# 5       finance  No other sector  Just email address/Online information
# ..          ...              ...                                    ...
# 413        tech           retail                   SSN/Personal details
# 414     finance  No other sector                   SSN/Personal details
# 415     finance  No other sector                Credit card information
# 416     finance  No other sector                Credit card information
# 417         web  No other sector  Just email address/Online information
#
# [417 rows x 13 columns]

# %%
dataframe_raw2.dtypes
# Out:
# organisation             object
# records_lost              int32
# year                      int32
# date                     object
# sector                   object
# method                   object
# data_sensitivity          int32
# source_name              object
# ID                        int32
# month                    object
# sector_1                 object
# sector_2                 object
# data_sensitivity_text    object
# dtype: object

# %%
dataframe_raw2 = dataframe_raw2[['ID', 'organisation', 'records_lost', 'date', 'year', 'month', 'sector', 'sector_1', 'sector_2', 
                                 'method', 'data_sensitivity', 'data_sensitivity_text', 'source_name']]
dataframe_raw2
# Out:
#       ID                organisation  records_lost      date  year     month  \
# 1    418                        Plex      15000000  Aug 2022  2022    August
# 2    419                     Twitter       5400000  Dec 2021  2021  December
# 3    420             Shanghai Police     500000000  Jul 2022  2022      July
# 4    421    City of Amagasaki, Japan        500000  Jun 2022  2022      June
# 5    417      Dubai Real Estate Leak        800000  May 2022  2022       May
# ..   ...                         ...           ...       ...   ...       ...
# 413    6             Hewlett Packard        200000  Mar 2006  2006     March
# 414    5             Ameritrade Inc.        200000  Apr 2005  2005     April
# 415    4                   Citigroup       3900000  Jun 2005  2005      June
# 416    3  Cardsystems Solutions Inc.      40000000  Jun 2005  2005      June
# 417    2                         AOL      92000000  Jun 2004  2004      June
#
#            sector    sector_1         sector_2       method  data_sensitivity  \
# 1             web         web  No other sector       hacked                 1
# 2             web         web  No other sector       hacked                 2
# 3       financial     finance  No other sector       hacked                 5
# 4      government  government  No other sector        oops!                 3
# 5       financial     finance  No other sector   inside job                 1
# ..            ...         ...              ...          ...               ...
# 413  tech, retail        tech           retail  lost device                 2
# 414       finance     finance  No other sector  lost device                 2
# 415       finance     finance  No other sector  lost device                 3
# 416       finance     finance  No other sector       hacked                 3
# 417           web         web  No other sector   inside job                 1
#
#                      data_sensitivity_text        source_name
# 1    Just email address/Online information       Ars technica
# 2                     SSN/Personal details  Bleeping Computer
# 3                             Full details       The Register
# 4                  Credit card information                BBC
# 5    Just email address/Online information                E24
# ..                                     ...                ...
# 413                   SSN/Personal details    Computer Weekly
# 414                   SSN/Personal details                NBC
# 415                Credit card information           NY Times
# 416                Credit card information              Wired
# 417  Just email address/Online information                CNN
#
# [417 rows x 13 columns]

# %%
## organisation changes #'D&B, Altegrity'
dataframe_raw2.loc[dataframe_raw2['organisation'] == '"Apple"', 'organisation'] = 'Apple'
dataframe_raw2.loc[dataframe_raw2['organisation'] == 'Experian / T-mobile', 'organisation'] = 'Experian'
dataframe_raw2.loc[dataframe_raw2['organisation'] == 'Linkedin', 'organisation'] = 'LinkedIn'
dataframe_raw2.loc[dataframe_raw2['organisation'] == 'T-mobile', 'organisation'] = 'T-Mobile'
dataframe_raw2.loc[dataframe_raw2['organisation'] == 'T-Mobile, Deutsche Telecom', 'organisation'] = 'T-Mobile'
dataframe_raw2.loc[dataframe_raw2['organisation'] == 'US Office of Personnel Management (2nd Breach)', 'organisation'] = 'US Office of Personnel Management'

# %%
a = dataframe_raw2.organisation.unique()
a.sort()
a
# Out:
# array(['500px', '8fit', 'AOL', 'AT&T', 'Aadhaar', 'Accendo Insurance Co.',
#        'Acer', 'Adobe', 'Adult Friend Finder', 'Advocate Medical Group',
#        'Affinity Health Plan, Inc.', 'Aimware', 'Air India', 'Al.type',
#        'Amazon', 'Amazon Reviews', 'Ameritrade Inc.', 'Animoto',
#        'Ankle & foot Center of Tampa Bay, Inc.', 'Anthem', 'Apollo',
#        'Apple', 'Armor Games', 'Artsy', 'AshleyMadison.com',
#        'Auction.co.kr', 'Australian Immigration Department',
#        'Australian National University', 'Automatic Data Processing',
#        'AvMed, Inc.', 'Avvo', 'BNY Mellon Shareowner Services',
#        'Banner Health', 'Bell', 'Betfair', 'Bethesda Game Studios',
#        'Blank Media Games', 'Blizzard',
#        'Blue Cross Blue Shield of Tennessee', 'Blur', 'BookMate',
#        'Boots Advantage Card', 'Brazzers', 'Brewdog', 'BriansClub',
#        'British Airways', 'Buchbinder Car Rentals',
#        'Bulgarian National Revenue Agency', 'CDEK', 'CEX',
#        'California Department of Child Support Services',
#        'Call of Duty / Activision', 'Canva', 'Capital One',
#        'CarPhone Warehouse', 'Cardsystems Solutions Inc.', 'Careem',
#        'Carefirst', 'Cathay Pacific Airways', 'Cellebrite', 'Cense AI',
#        'Central Hudson Gas & Electric', 'CheckFree Corporation',
#        'Chile Ministry Of Education', 'China Software Developer Network',
#        'Chinese gaming sites', 'Chinese resume leak', 'Chtrbox',
#        'Citigroup', 'City and Hackney Teaching Primary Care Trust',
#        'City of Amagasaki, Japan', 'Classified Iraq War documents',
#        'Click2Gov', 'Clinton campaign', 'ClixSense', 'CoffeeMeetsBagel',
#        'Coinmama', 'Colorado government', 'Community Health Systems',
#        'Compass Bank', 'Contact tracing data',
#        'Countrywide Financial Corp', 'Court Ventures',
#        'Crescent Health Inc., Walgreens', 'D&B, Altegrity', 'DaFont',
#        'Dai Nippon Printing', 'Dailymotion', 'DataCamp',
#        'Deep Root Analytics', 'Dell', 'Desjardins Group', 'Digital Ocean',
#        'Disqus', 'Dixons Carphone', 'Dominios Pizzas (France)',
#        'DoorDash', 'Driving Standards Agency', 'Drizly', 'Dropbox',
#        'Drupal', 'Dubai Real Estate Leak', 'Dubsmash', 'Dutch Government',
#        'EasyJet', 'Ebay', 'Educational Credit Management Corp',
#        'Eisenhower Medical Center',
#        'Emergency Healthcare Physicians, Ltd.', 'Emory Healthcare',
#        'Epik', 'Epsilon', 'Equifax', 'Estonian gov',
#        'European Central Bank', 'Evernote', 'Experian', 'Experian Brazil',
#        'Experian SA', 'EyeEm', 'Facebook',
#        'Fidelity National Information Services', 'Firebase', 'FlexBooker',
#        'Fling', 'Florida Department of Juvenile Justice', 'Formspring',
#        'Fotolog', 'Friend Finder Network', 'GEDmatch', 'GMail',
#        'GS Caltex', 'Gab', 'Gamigo', 'Gap Inc', 'Gawker.com', 'Ge.tt',
#        'Global Payments', 'GoDaddy', 'Google+', 'GovPayNow.com',
#        'Greek government', 'Grindr', 'Guntrader', 'HSBC Turkey',
#        'Hacking Team', 'Hannaford Brothers Supermarket Chain',
#        'HauteLook', 'Health Net', 'Health Net - IBM', 'Heartland',
#        'Helse Sør-Øst RHF', 'Heroku', 'Hewlett Packard', 'High Tail Hall',
#        'Ho Mobile', 'Home Depot', 'Honda Canada',
#        'Hong Kong Registration & Electoral Office', 'Houzz', 'IRS',
#        'Imgur', 'Indian citizens', 'Indiana University', 'Instagram',
#        'Interpark', 'Invest Bank', 'Israeli government', 'Ixigo',
#        'JP Morgan Chase', 'Japan Airlines', 'KDDI', 'KM.ru & Nival',
#        'KT Corp.', 'Kirkwood Community College', 'Korea Credit Bureau',
#        'Kromtech', 'LINE Pay', 'Last.fm', 'Ledger',
#        'Lincoln Medical & Mental Health Center', 'LinkedIn',
#        'LinkedIn, eHarmony, Last.fm', 'Linux Ubuntu forums',
#        'Living Social', 'LocalBlox', 'Lynda.com', 'MBM Company',
#        'MGM Hotels', 'MSpy', 'MacDonalds', 'MacRumours.com', 'Mail. ru',
#        'Mailchimp', 'Malaysian medical practitioners',
#        'Malaysian telcos & MVNOs', 'Marriott Hotels',
#        'Marriott International', 'Massachusetts Government',
#        'Massive American business hack', 'Medicaid',
#        'Medicare & Medicaid', 'Meet Mindful',
#        'Memorial Healthcare System', 'Microsoft', 'Militarysingles.com',
#        'Minecraft', 'Monster.com', 'Morgan Stanley Smith Barney',
#        'Mossack Fonseca', 'Mount Olympus', 'Mozilla',
#        'Mutuelle Generale de la Police', 'MyFitnessPal', 'MyHeritage',
#        'MySpace', 'NASDAQ', 'NHS', 'NMBS', 'Nametests',
#        'National Security Agency', 'Neiman Marcus', 'Nemours Foundation',
#        'Network Solutions', 'New York City Health & Hospitals Corp.',
#        'New York State Electric & Gas', 'New York Taxis', 'Newegg',
#        'Nexon Korea Corp', 'Nintendo', 'Norwegian Tax Authorities',
#        'Nvidia', 'OVH', 'Office of the Texas Attorney General',
#        'Ohio State University', 'Okta', 'Omiai dating app',
#        'Open Subtitles', 'Orbitz', 'Oregon Department of Motor Vehicles',
#        'OxyData', 'Pakistani mobile operators', 'Pandora Papers',
#        'Panerabread', 'Park Mobile', 'PayAsUGym', 'PayHere', 'Peloton',
#        'Petflow', 'Philippines’ Commission on Elections', 'Plex',
#        'Premera', 'Privatization Agency of the Republic of Serbia',
#        'Quest Diagnostics', 'Quora', 'RBS Worldpay', 'Red Cross',
#        'Red Cross Blood Service', 'Restaurant Depot', 'River City Media',
#        'Robinhood', 'RockYou!', 'Roll20', 'RootsWeb', 'Royal Enfield',
#        'SKY Brasil', 'SVR Tracking', 'Saks and Lord & Taylor',
#        'San Francisco Public Utilities Commission', 'Sanrio', 'Scribd',
#        'Seacoast Radiology, PA', 'Securus Technologies', 'Sega',
#        'Service Personnel and Veterans Agency (UK)', 'Shanghai Police',
#        'ShareThis', 'SingHealth', 'Slack', 'SnapChat', 'Snapchat',
#        'SolarWinds', 'Sony Online Entertainment', 'Sony PSN',
#        'Sony Pictures', 'South Carolina Government',
#        'South Carolina State Dept. of Revenue',
#        'South Shore Hospital, Massachusetts',
#        'Southern California Medical-Legal Consultants', 'Spambot',
#        'Spartanburg Regional Healthcare System', 'Spotify',
#        'Stanford University', 'Staples', 'Star Alliance', 'Starbucks',
#        'State of Texas', 'Steam', 'Stratfor', 'Stronghold Kingdoms',
#        'Suprema', 'Sutter Medical Foundation', 'Swedish Transport Agency',
#        'Syniverse', 'Syrian government', 'T-Mobile', 'TD Ameritrade',
#        'TIO Networks', 'TK / TJ Maxx', 'TalkTalk', 'Target', 'Telegram',
#        'TerraCom & YourTel', 'Tesco Clubcard', 'Texas Lottery',
#        'Texas voter records', 'Thailand visitors', 'The Hospital Group',
#        'Three', 'Three Iranian banks', 'Tianya', 'TicketFly',
#        'Ticketmaster', 'Toyota', 'Travelio', 'Tricare',
#        'Triple-S Salud, Inc.', 'Tumblr', 'Turkish citizenship database',
#        'Twitch', 'Twitter', 'UCLA Health', 'UK Home Office',
#        'UK Ministry of Defence', 'UK Revenue & Customs', 'UPS',
#        'US Customs and Border Protection', 'US Dept of Vet Affairs',
#        'US Federal Reserve Bank of Cleveland', 'US Law Enforcement',
#        'US Marshals Service', 'US Military', 'US National Guard',
#        'US Office of Personnel Management', 'Uber', 'UbiSoft', 'Ubiquiti',
#        'Ubuntu', 'University of California Berkeley',
#        'University of Delaware', 'University of Miami',
#        'University of Utah Hospitals & Clinics',
#        'University of Wisconsin - Milwaukee', 'Unknown', 'Urban Massage',
#        'VK', 'VTech', 'VW', 'Viacom', 'ViewFines', 'Virgin Media',
#        'Virginia Prescription Monitoring Program', 'Vision Direct',
#        'Vodafone', 'Vårdguiden', 'Washington Post',
#        'Washington State Dpt of Licensing',
#        'Washington State court system', 'Waterly', 'Wawa', 'Weebly',
#        "Wendy's", 'Whitepages', 'WiFi Finder', 'Wonga', 'World Check',
#        'Writerspace.com', 'Yahoo', 'Yahoo Japan', 'Yahoo Voices',
#        'Yale University', 'YouNow', 'Zappos', 'Zhenhua', 'Zomato', 'Zoom',
#        'db8151dd', 'ssndob.ms', 'uTorrent'], dtype=object)

# %% [markdown]
# ## Save Dataset to Folder

# %%
dataframe_raw2.to_csv("./Dataset/Dataset.csv", index = False)
